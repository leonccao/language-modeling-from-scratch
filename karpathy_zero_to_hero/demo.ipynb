# %% [markdown]
# # MicroGrad guided demo
#
# This notebook is a practice version of Karpathy's upstream `demo.ipynb`. Complete the `micrograd` package first, then use it here to train a binary classifier end to end.

# %% [markdown]
# ## Learning checkpoints
#
# You will construct an MLP, define max-margin loss with L2 regularization, optimize it with SGD, and visualize its decision boundary. Exercise cells state behavioral requirements but intentionally omit the implementation.

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_moons

# %matplotlib inline

# %%
from micrograd.engine import Value
from micrograd.nn import MLP

# %%
np.random.seed(1337)
random.seed(1337)

# %% [markdown]
# ## Dataset
#
# Create 100 noisy two-moons samples and encode the two classes as `-1` and `1`. This setup is provided so the exercises remain focused on neural networks.

# %%
X, y = make_moons(n_samples=100, noise=0.1)
y = y * 2 - 1

plt.figure(figsize=(5, 5))
plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap="jet")
plt.title("Two-moons training data")
plt.show()

# %% [markdown]
# ## Exercise 1: construct the model
#
# Create an MLP with two inputs, two hidden layers of width 16, and one scalar output. Confirm its printed structure and parameter count before continuing.

# %%
# TODO: assign the required MLP to model, then inspect it.
raise NotImplementedError("Exercise 1: construct the model")

# %% [markdown]
# ## Exercise 2: define the objective
#
# Implement `loss(batch_size=None)` so it optionally selects a random batch, evaluates the model, combines mean binary max-margin loss with L2 parameter regularization, and returns `(total_loss, accuracy)`. The loss must be a `Value`; accuracy must be a Python number.

# %%
def loss(batch_size=None):
    """Return regularized max-margin loss and classification accuracy."""
    raise NotImplementedError("Exercise 2: implement the objective")


# Checkpoint: evaluate loss() once and inspect both returned values.

# %% [markdown]
# ## Exercise 3: optimize with SGD
#
# Train for 100 steps. Each step must evaluate the objective, clear existing gradients, backpropagate, and update every parameter with SGD. Use a learning rate that decreases linearly from `1.0` toward `0.1`, and print loss and accuracy as training progresses.

# %%
# TODO: implement the complete optimization loop.
raise NotImplementedError("Exercise 3: train the model")

# %% [markdown]
# ## Exercise 4: visualize the decision boundary
#
# Evaluate the trained model over the provided mesh, convert scalar scores into binary predictions, reshape them to the mesh, and run the plotting code.

# %%
h = 0.25
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(
    np.arange(x_min, x_max, h),
    np.arange(y_min, y_max, h),
)
Xmesh = np.c_[xx.ravel(), yy.ravel()]

# TODO: assign a boolean prediction array with shape xx.shape to Z.
raise NotImplementedError("Exercise 4: predict over the mesh")

plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Learned decision boundary")
plt.show()

# %% [markdown]
# ## Completion criteria
#
# The notebook is complete when all cells run from a fresh kernel, loss decreases during training, accuracy improves substantially above chance, and the final plot separates the two moon-shaped classes.
